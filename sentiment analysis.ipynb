# %%
import numpy as np 
import tensorflow 
from tensorflow import keras 
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import pad_sequences
docs=[
    'go pakistan',
        'pakistan pakistan',
        'dil dil pakistan',
        'jeetega bhai jeetega pakistan jeetega',
        'pakistan zindabad',
        'babar babar',
        'shaheen shaheen',
        'afridi afridi',
        'quaid e azam zindabad',
        'hum honge kamyab' 
]

# %%
tokenizer=Tokenizer()
tokenizer.fit_on_texts(docs)

# %%
tokenizer.word_index
# Out:
# {'pakistan': 1,
#  'jeetega': 2,
#  'dil': 3,
#  'zindabad': 4,
#  'babar': 5,
#  'shaheen': 6,
#  'afridi': 7,
#  'go': 8,
#  'bhai': 9,
#  'quaid': 10,
#  'e': 11,
#  'azam': 12,
#  'hum': 13,
#  'honge': 14,
#  'kamyab': 15}

# %%
sequences = tokenizer.texts_to_sequences(docs)
sequences
# Out:
# [[8, 1],
#  [1, 1],
#  [3, 3, 1],
#  [2, 9, 2, 1, 2],
#  [1, 4],
#  [5, 5],
#  [6, 6],
#  [7, 7],
#  [10, 11, 12, 4],
#  [13, 14, 15]]

# %%
tokenizer.word_counts
# Out:
# OrderedDict([('go pakistan', 1),
#              ('pakistan pakistan', 1),
#              ('dil dil pakistan', 1),
#              ('jeetega bhai jeetega pakistan jeetega', 1),
#              ('pakistan zindabad', 1),
#              ('babar babar', 1),
#              ('shaheen shaheen', 1),
#              ('afridi afridi', 1),
#              ('quaid e azam zindabad', 1),
#              ('hum honge kamyab', 1)])

# %%
sequences=pad_sequences(sequences,padding='pre')

# %%
sequences
# Out:
# array([[ 0,  0,  0,  8,  1],
#        [ 0,  0,  0,  1,  1],
#        [ 0,  0,  3,  3,  1],
#        [ 2,  9,  2,  1,  2],
#        [ 0,  0,  0,  1,  4],
#        [ 0,  0,  0,  5,  5],
#        [ 0,  0,  0,  6,  6],
#        [ 0,  0,  0,  7,  7],
#        [ 0, 10, 11, 12,  4],
#        [ 0,  0, 13, 14, 15]], dtype=int32)
